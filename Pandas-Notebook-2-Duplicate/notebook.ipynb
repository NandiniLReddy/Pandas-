# %% [markdown]
# # 450+ Practice Questions That Will Make You a Pandas, NumPy, and SQL Pro!

# %% [markdown]
# Author: Avi Chawla
#
# LinkedIn: https://www.linkedin.com/in/avi-chawla/
#
# Read my blogs here: https://medium.com/@avi_chawla

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook has been created for you to practice three of the most common tools used in building any machine learning or data science applications, i.e., Pandas, NumPy, and SQL!

# %% [markdown]
# The practice questions provided will serve as a great resource for those who are looking to familiarize themselves with some of the most common functions used in these tools.

# %% [markdown]
# Appropriate descriptions have been provided for all the questions in this entire exercise which will help you navigate through this exercise easily. If a dataset is to be loaded in the Python environment, that has also been provided for you. You can find it on the right panel in the Files section. Do NOT delete any of the files/folders listed there.

# %% [markdown]
# The whole exercise has been divided into nine separate notebooks. Below are the links to all the other notebooks for you to jump from one notebook to another:

# %% [markdown]
# - **Pandas**
#
# 1. Pandas Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-1-d693ac55-6455-40cf-ae34-867c6a02014e/%2Fnotebook.ipynb)
# 2. Pandas Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-dataset-7e3b6755-5d4b-464b-9b75-9c84667ae3bd/%2Fnotebook.ipynb) **(This Notebook)**
#
# 3. Pandas Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/%2Fnotebook.ipynb)
#
# 4. Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb)
#
# - **NumPy**
#
# 1. NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/%2Fnotebook.ipynb)
#
# 2. NumPy Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-2-4456411e-2ddd-426d-8027-4881080027db/%2Fnotebook.ipynb)
#
# 3. NumPy Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-3-e6587114-b580-4249-b599-540de859e603/%2Fnotebook.ipynb)
#
# - **SQL**
#
# 1. SQL Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-1-eac9d782-a9b1-4e84-a1f9-af14080a6121/%2Fnotebook.ipynb)
#
# 2. SQL Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-2-1914b214-be03-44a1-be63-ad99e98be639/%2Fnotebook.ipynb)

# %% [markdown]
# ## How to use this notebook?

# %% [markdown]
# At the top right corner, you will find a Duplicate button. This will allow you to create a unique notebook for your own practice and write solutions to the question listed in this notebook.

# %% [markdown]
# If you face any issues or have any feedback, feel free to reach out to me (Avi Chawla) either on Linkedin: https://www.linkedin.com/in/avi-chawla/ or write an email to avi@dsscholar[dot]com.

# %% [markdown]
# Let's begin 🚀!

# %% [markdown]
# # Pandas Notebook 2

# %% [markdown]
# ### 31. Read the CSV file.

# %%
import pandas as pd
file_name = "employee_dataset.csv"

df = pd.read_csv(file_name)
df
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 32. Print the first 5 rows.

# %%
df_temp = df.iloc[0:5]

print(df_temp)
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8

# %%
df_temp = df.head(5)

print(df_temp)
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 0  Palestinian Territory           321520         Full Time              3.9
# 1       Marshall Islands           589090         Full Time              4.3
# 2               Anguilla           630890         Full Time              3.1
# 3   Syrian Arab Republic           116400         Full Time              3.1
# 4               Dominica           523499         Full Time              4.8

# %% [markdown]
# ### 33. Print the last 10 rows.

# %%
df_temp = df.iloc[-10:]
print(df_temp)
# Out:
#                      Name                  Company_Name  \
# 299990      Monica Bender    Wallace, Smith and Shepard
# 299991  William Rodriguez                     Scott Inc
# 299992    Steven Thornton      Baker, Allen and Edwards
# 299993         Terry Hill       White, Mcclain and Cobb
# 299994      Kelly Bennett       White, Mcclain and Cobb
# 299995         Nancy Neal              Bullock-Carrillo
# 299996     Michele Butler  Johnston, Fleming and Tanner
# 299997        Lynn Wilson                 Nichols-James
# 299998      Lindsey Keith                 Nichols-James
# 299999      Karen Delgado                James and Sons
#
#                   Employee_Job_Title      Employee_City Employee_Country  \
# 299990           Production engineer   New Cindychester       Bangladesh
# 299991                    Ergonomist          Whiteside      New Zealand
# 299992               Patent examiner         Aliciafort            Benin
# 299993  Investment banker, corporate   New Cindychester           Sweden
# 299994     Radiographer, therapeutic           Wardfort             Fiji
# 299995                   Optometrist  North Melissafurt            Samoa
# 299996                 Administrator         Aliciafort             Cuba
# 299997                 Administrator   New Cindychester          Bolivia
# 299998                          Make       Whitakerbury   Western Sahara
# 299999                       Actuary     New Russellton   United Kingdom
#
#         Employee_Salary Employment_Status  Employee_Rating
# 299990           852660         Full Time              3.0
# 299991           214400         Full Time              1.5
# 299992            60240         Full Time              4.3
# 299993           414720            Intern              2.3
# 299994           182270         Full Time              3.6
# 299995            99670            Intern              3.3
# 299996           949580            Intern              2.6
# 299997           802830         Full Time              0.6
# 299998           257240         Full Time              2.4
# 299999           575770            Intern              3.3

# %% [markdown]
# ### 34. Print the number of rows.

# %%
rows = len(df)

print(rows)
# Out:
# 300000

# %%
df.shape[0]
# Out:
# 300000

# %% [markdown]
# ### 35. Print the number of columns.

# %%
columns = df.shape[1]

print(columns)
# Out:
# 8

# %%
len(df.columns)
# Out:
# 8

# %% [markdown]
# ### 36. Print all column names.

# %%
column_names = df.columns


print(column_names)
# Out:
# Index(['Name', 'Company_Name', 'Employee_Job_Title', 'Employee_City',
#        'Employee_Country', 'Employee_Salary', 'Employment_Status',
#        'Employee_Rating'],
#       dtype='object')

# %% [markdown]
# ### 37. Print the mean of Employee_Salary.

# %%
df['Employee_Salary'].mean()
# Out:
# 500224.20772666665

# %% [markdown]
# ### 38. Print the mean of Employee_Rating.

# %%
df['Employee_Rating'].mean()
# Out:
# 2.5059550000000006

# %% [markdown]
# ### 39. Print the number of distinct Company_Name.

# %%
df.groupby('Company_Name').nunique().count()
# Out:
# Name                  15
# Employee_Job_Title    15
# Employee_City         15
# Employee_Country      15
# Employee_Salary       15
# Employment_Status     15
# Employee_Rating       15
# dtype: int64

# %% [markdown]
# ### 40. Print all the distinct Company_Name.

# %%
df.Company_Name.unique()
# Out:
# array(['James and Sons', 'Nichols-James', 'Scott Inc',
#        'Johnston, Fleming and Tanner', 'Baker, Allen and Edwards',
#        'Andrade LLC', 'Matthews Inc', 'Taylor-Ramos',
#        'Campos, Reynolds and Mccormick', 'White, Mcclain and Cobb',
#        'Thomas-Spencer', 'Bullock-Carrillo', 'Marshall-Holloway',
#        'Wallace, Smith and Shepard', 'Nelson-Li'], dtype=object)

# %% [markdown]
# ### 41. Print the number of employees working in the company "Nichols-James".

# %%
df[df['Company_Name']=='Nichols-James']['Name'].count()
# Out:
# 19911

# %%
df[df['Company_Name']=='Nichols-James'].count()
# Out:
# Name                  19911
# Company_Name          19911
# Employee_Job_Title    19911
# Employee_City         19911
# Employee_Country      19911
# Employee_Salary       19911
# Employment_Status     19911
# Employee_Rating       19911
# dtype: int64

# %% [markdown]
# ### 42-44. Print the maximum, minimum and median Employee_Salary.

# %%
df['Employee_Salary'].agg(['max','min','median'])
# Out:
# max       999990.0
# min            0.0
# median    500780.0
# Name: Employee_Salary, dtype: float64

# %% [markdown]
# ### 45-49. Print the distribution of the following columns: (the frequency of individual entries).

# %% [markdown]
# 1. Company_Name

# %%
df['Company_Name'].describe()
# Out:
# count        300000
# unique           15
# top       Scott Inc
# freq          20390
# Name: Company_Name, dtype: object

# %%
df['Company_Name'].value_counts()
# Out:
# Scott Inc                         20390
# White, Mcclain and Cobb           20261
# Thomas-Spencer                    20142
# Nelson-Li                         20132
# Taylor-Ramos                      20122
# Baker, Allen and Edwards          20084
# Matthews Inc                      20083
# Bullock-Carrillo                  20063
# Andrade LLC                       19983
# Campos, Reynolds and Mccormick    19927
# Nichols-James                     19911
# James and Sons                    19868
# Marshall-Holloway                 19859
# Johnston, Fleming and Tanner      19811
# Wallace, Smith and Shepard        19364
# Name: Company_Name, dtype: int64

# %% [markdown]
# 2. Employee_Job_Title

# %%
df['Employee_Job_Title'].value_counts()
# Out:
# Diplomatic Services operational officer                  30137
# Administrator                                            15222
# Garment/textile technologist                             15183
# Trading standards officer                                15155
# Patent examiner                                          15085
# Armed forces logistics/support/administrative officer    15050
# Retail merchandiser                                      15033
# Energy manager                                           15033
# Actuary                                                  15030
# Investment banker, corporate                             15008
# Ergonomist                                               15006
# Production engineer                                      15003
# Equities trader                                          15000
# Naval architect                                          14905
# Radiographer, therapeutic                                14882
# Regulatory affairs officer                               14869
# Optometrist                                              14838
# Sales promotion account executive                        14820
# Make                                                     14741
# Name: Employee_Job_Title, dtype: int64

# %% [markdown]
# 3. Employee_City

# %%
df['Employee_City'].value_counts()
# Out:
# North Melissafurt    30209
# Kristaburgh          30204
# Wardfort             30097
# Ricardomouth         30052
# Aliciafort           30037
# New Russellton       30001
# West Jamesview       29941
# Whitakerbury         29854
# Whiteside            29849
# New Cindychester     29756
# Name: Employee_City, dtype: int64

# %% [markdown]
# 4. Employee_Country

# %%
df['Employee_Country'].value_counts()
# Out:
# Congo                                                  2413
# Korea                                                  2301
# British Indian Ocean Territory (Chagos Archipelago)    1344
# Egypt                                                  1322
# Turkey                                                 1308
#                                                        ...
# Saint Vincent and the Grenadines                       1147
# Czech Republic                                         1145
# Mexico                                                 1144
# Mauritania                                             1139
# Ukraine                                                1133
# Name: Employee_Country, Length: 243, dtype: int64

# %% [markdown]
# 5. Employment_Status

# %%
df['Employment_Status'].value_counts()
# Out:
# Full Time    240010
# Intern        59990
# Name: Employment_Status, dtype: int64

# %% [markdown]
# ### 50. Print the company with the most number of employees.

# %%
df['Company_Name'].value_counts().idxmax()
# Out:
# 'Scott Inc'

# %%
df['Company_Name'].value_counts().head(1)
# Out:
# Scott Inc    20390
# Name: Company_Name, dtype: int64

# %% [markdown]
# ### 51. Print the number of employees in the above company.

# %%
df['Company_Name'].value_counts()[0]
# Out:
# 20390

# %% [markdown]
# ### 52. Print the company with the least number of employees.

# %%
df['Company_Name'].value_counts().idxmin()
# Out:
# 'Wallace, Smith and Shepard'

# %%
df['Company_Name'].value_counts().tail(1)
# Out:
# Wallace, Smith and Shepard    19364
# Name: Company_Name, dtype: int64

# %% [markdown]
# ### 53. Print the number of employees in the above company.

# %%
df['Company_Name'].value_counts().tail(1)[0]
# Out:
# 19364

# %% [markdown]
# ### 54. Print the employee details with the maximum salary

# %%
df
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %%
df.groupby('Name')['Employee_Salary'].max().head(1)
# Out:
# Name
# Aaron Abbott    440590
# Name: Employee_Salary, dtype: int64

# %% [markdown]
# ### 55. Print the employee details with the maximum rating

# %%
df.groupby('Name')['Employee_Rating'].max().head(1)
# Out:
# Name
# Aaron Abbott    4.1
# Name: Employee_Rating, dtype: float64

# %% [markdown]
# ### 56. Print the Company_Name with most number of employees in 'Wardfort' city.

# %%
df
# Out:
#                   Name                  Company_Name  \
# 0       Spencer Adkins                James and Sons
# 1         Julie Morton                 Nichols-James
# 2         Matthew Hall                     Scott Inc
# 3           Brad Scott  Johnston, Fleming and Tanner
# 4        Theresa Owens      Baker, Allen and Edwards
# ...                ...                           ...
# 299995      Nancy Neal              Bullock-Carrillo
# 299996  Michele Butler  Johnston, Fleming and Tanner
# 299997     Lynn Wilson                 Nichols-James
# 299998   Lindsey Keith                 Nichols-James
# 299999   Karen Delgado                James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#              Employee_Country  Employee_Salary Employment_Status  \
# 0       Palestinian Territory           321520         Full Time
# 1            Marshall Islands           589090         Full Time
# 2                    Anguilla           630890         Full Time
# 3        Syrian Arab Republic           116400         Full Time
# 4                    Dominica           523499         Full Time
# ...                       ...              ...               ...
# 299995                  Samoa            99670            Intern
# 299996                   Cuba           949580            Intern
# 299997                Bolivia           802830         Full Time
# 299998         Western Sahara           257240         Full Time
# 299999         United Kingdom           575770            Intern
#
#         Employee_Rating
# 0                   3.9
# 1                   4.3
# 2                   3.1
# 3                   3.1
# 4                   4.8
# ...                 ...
# 299995              3.3
# 299996              2.6
# 299997              0.6
# 299998              2.4
# 299999              3.3
#
# [300000 rows x 8 columns]

# %%
df[df['Employee_City']=='Wardfort']['Company_Name'].value_counts().head(1)
# Out:
# White, Mcclain and Cobb    2069
# Name: Company_Name, dtype: int64

# %% [markdown]
# ### 57. Change the Data type of 'Employee_Salary' column to float.

# %%
df['Employee_Salary']=df['Employee_Salary'].astype(float)

# %% [markdown]
# ### 58. Print the Employee_City with the most number of 'Production engineer'.

# %%
df.columns
# Out:
# Index(['Name', 'Company_Name', 'Employee_Job_Title', 'Employee_City',
#        'Employee_Country', 'Employee_Salary', 'Employment_Status',
#        'Employee_Rating'],
#       dtype='object')

# %%
df[df['Employee_Job_Title']=='Production engineer']['Employee_City'].value_counts().head(1)
# Out:
# Aliciafort    1588
# Name: Employee_City, dtype: int64

# %% [markdown]
# ### 59. Print the Company_Name with the most number of Full-time Employees.

# %%
df[df['Employment_Status']=='Full Time']['Company_Name'].value_counts().head(1)
# Out:
# Scott Inc    16396
# Name: Company_Name, dtype: int64

# %% [markdown]
# ### .60. Print the Company_Name with the highest average 'Employee_Rating'.

# %%
df.groupby('Company_Name')['Employee_Rating'].idxmax().head(1)
# Out:
# Company_Name
# Andrade LLC    517
# Name: Employee_Rating, dtype: int64

# %% [markdown]
# ### 61. Print the number of employees working in 'Ricardomouth' and 'Kristaburgh' location combined.

# %%
df[(df['Employee_City']=='Ricardomouth') | (df['Employee_City']=='Kristaburgh')]['Name'].count()
# Out:
# 60256

# %%
df[df['Employee_City'].isin(['Ricardomouth','Kristaburgh'])]['Name'].count()
# Out:
# 60256

# %% [markdown]
# ### 62. Print the distinct Company_Name corresponding to the 5 highest paid employees in the dataset.

# %%
df.sort_values('Employee_Salary', ascending=False)['Company_Name'].head(5).unique()
# Out:
# array(['Taylor-Ramos', 'Thomas-Spencer', 'White, Mcclain and Cobb',
#        'Campos, Reynolds and Mccormick'], dtype=object)

# %%
max_salary=df['Employee_Salary'].idxmax()
df.loc[max_salary, 'Company_Name']
# Out:
# 'Taylor-Ramos'

# %%
df.nlargest(5, 'Employee_Salary')['Company_Name'].unique()
# Out:
# array(['Taylor-Ramos', 'White, Mcclain and Cobb', 'Thomas-Spencer',
#        'Campos, Reynolds and Mccormick'], dtype=object)

# %% [markdown]
# ### 63. Check if there are any duplicate rows in the DataFrame.

# %%
df.duplicated().count()
# Out:
# 300000

# %% [markdown]
# ### 64. Check if any of the columns has NaN values.

# %%
df.isnull().count()
# Out:
# Name                  300000
# Company_Name          300000
# Employee_Job_Title    300000
# Employee_City         300000
# Employee_Country      300000
# Employee_Salary       300000
# Employment_Status     300000
# Employee_Rating       300000
# dtype: int64

# %% [markdown]
# ### 65. Print the data type of every column in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Name                300000 non-null  object
#  1   Company_Name        300000 non-null  object
#  2   Employee_Job_Title  300000 non-null  object
#  3   Employee_City       300000 non-null  object
#  4   Employee_Country    300000 non-null  object
#  5   Employee_Salary     300000 non-null  float64
#  6   Employment_Status   300000 non-null  object
#  7   Employee_Rating     300000 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 18.3+ MB

# %% [markdown]
# ### 66. Print the Company_Name column only as a Series

# %%
pd.Series(df['Company_Name'])
# Out:
# 0                       James and Sons
# 1                        Nichols-James
# 2                            Scott Inc
# 3         Johnston, Fleming and Tanner
# 4             Baker, Allen and Edwards
#                       ...
# 299995                Bullock-Carrillo
# 299996    Johnston, Fleming and Tanner
# 299997                   Nichols-James
# 299998                   Nichols-James
# 299999                  James and Sons
# Name: Company_Name, Length: 300000, dtype: object

# %% [markdown]
# ### 67. Print the Company_Name column only as a DataFrame

# %%
pd.DataFrame(df['Company_Name'])
# Out:
#                         Company_Name
# 0                     James and Sons
# 1                      Nichols-James
# 2                          Scott Inc
# 3       Johnston, Fleming and Tanner
# 4           Baker, Allen and Edwards
# ...                              ...
# 299995              Bullock-Carrillo
# 299996  Johnston, Fleming and Tanner
# 299997                 Nichols-James
# 299998                 Nichols-James
# 299999                James and Sons
#
# [300000 rows x 1 columns]

# %% [markdown]
# ### 68. Select the 'Employee_Job_Title' and 'Employee_City' column.

# %%
df.columns
# Out:
# Index(['Name', 'Company_Name', 'Employee_Job_Title', 'Employee_City',
#        'Employee_Country', 'Employee_Salary', 'Employment_Status',
#        'Employee_Rating'],
#       dtype='object')

# %%
temp=df[['Employee_Job_Title', 'Employee_City']]
# Out:
#                              Employee_Job_Title      Employee_City
# 0                               Equities trader     New Russellton
# 1       Diplomatic Services operational officer  North Melissafurt
# 2                    Regulatory affairs officer           Wardfort
# 3                           Production engineer     West Jamesview
# 4                           Production engineer          Whiteside
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
# [300000 rows x 2 columns]

# %% [markdown]
# ### 69. Print the number of employees with Employee_Rating greater than the average Employee_Rating

# %%
df['Employee_Rating'].mean()
# Out:
# 2.5059550000000006

# %%
df.columns
# Out:
# Index(['Name', 'Company_Name', 'Employee_Job_Title', 'Employee_City',
#        'Employee_Country', 'Employee_Salary', 'Employment_Status',
#        'Employee_Rating'],
#       dtype='object')

# %%
df[df['Employee_Rating']>df['Employee_Rating'].mean()]['Name'].count()
# Out:
# 147548

# %% [markdown]
# ### 70. Find the employee which has the maximum salary among the ones with  the minimum Employee_Rating

# %%
df[df['Employee_Rating']==df['Employee_Rating'].min()]['Employee_Salary'].max()
# Out:
# 999690.0

# %%
min_rating = df['Employee_Rating'].min()
max_salary = df[df['Employee_Rating'] == min_rating]['Employee_Salary'].max()
employee = df[(df['Employee_Rating'] == min_rating) & (df['Employee_Salary'] == max_salary)]['Name'].values[0]
employee
# Out:
# 'Austin Poole'

# %% [markdown]
# ### 71. Sort the DataFrame in ascending order of Employee_Salary

# %%
df.sort_values('Employee_Salary', ascending=True)
# Out:
#                       Name                    Company_Name  \
# 54531      Kristen Vasquez         White, Mcclain and Cobb
# 205070  Courtney Singleton         White, Mcclain and Cobb
# 185700          Vanessa Wu  Campos, Reynolds and Mccormick
# 226792          Penny Meza      Wallace, Smith and Shepard
# 229395         Grace Smith    Johnston, Fleming and Tanner
# ...                    ...                             ...
# 23536        Dennis Sexton  Campos, Reynolds and Mccormick
# 50461        Logan Jackson         White, Mcclain and Cobb
# 153993       Jason Jenkins                    Taylor-Ramos
# 51642      Richard Kennedy                  Thomas-Spencer
# 70356          Anna Lawson                    Taylor-Ramos
#
#                                        Employee_Job_Title      Employee_City  \
# 54531   Armed forces logistics/support/administrative ...           Wardfort
# 205070                       Garment/textile technologist   New Cindychester
# 185700                                    Patent examiner  North Melissafurt
# 226792                          Trading standards officer           Wardfort
# 229395                          Trading standards officer     West Jamesview
# ...                                                   ...                ...
# 23536             Diplomatic Services operational officer        Kristaburgh
# 50461                                          Ergonomist           Wardfort
# 153993                  Sales promotion account executive         Aliciafort
# 51642                                      Energy manager         Aliciafort
# 70356                                 Production engineer        Kristaburgh
#
#               Employee_Country  Employee_Salary Employment_Status  \
# 54531                  Bermuda              0.0         Full Time
# 205070                Ethiopia              0.0         Full Time
# 185700                  Zambia             10.0         Full Time
# 226792                 Albania             10.0         Full Time
# 229395  Libyan Arab Jamahiriya             10.0            Intern
# ...                        ...              ...               ...
# 23536           United Kingdom         999970.0         Full Time
# 50461             Saint Helena         999980.0         Full Time
# 153993                Pakistan         999980.0         Full Time
# 51642             Cook Islands         999980.0         Full Time
# 70356                  Lesotho         999990.0         Full Time
#
#         Employee_Rating
# 54531               3.4
# 205070              2.8
# 185700              1.3
# 226792              0.7
# 229395              1.1
# ...                 ...
# 23536               0.9
# 50461               2.0
# 153993              2.6
# 51642               2.4
# 70356               4.0
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 72. Sort the DataFrame in descending order of Employee_Rating

# %%
df.sort_values('Employee_Rating', ascending=False)
# Out:
#                      Name                  Company_Name  \
# 222544        Laura Lopez                     Scott Inc
# 26453     Adriana Ferrell  Johnston, Fleming and Tanner
# 141265     Russell Dorsey      Baker, Allen and Edwards
# 184624  Katherine Jenkins                  Matthews Inc
# 70533     Brittney Greene                James and Sons
# ...                   ...                           ...
# 50012           Sara King                  Matthews Inc
# 289392       Heather Paul                     Nelson-Li
# 14752     Kathryn Goodwin      Baker, Allen and Edwards
# 204854          Nina Yang    Wallace, Smith and Shepard
# 242616   Melissa Johnston                  Matthews Inc
#
#                                        Employee_Job_Title     Employee_City  \
# 222544                                    Equities trader         Whiteside
# 26453                                          Ergonomist        Aliciafort
# 141265                                        Optometrist        Aliciafort
# 184624                                               Make  New Cindychester
# 70533                                      Energy manager      Ricardomouth
# ...                                                   ...               ...
# 50012             Diplomatic Services operational officer         Whiteside
# 289392                                               Make          Wardfort
# 14752                                      Energy manager  New Cindychester
# 204854  Armed forces logistics/support/administrative ...          Wardfort
# 242616            Diplomatic Services operational officer         Whiteside
#
#                    Employee_Country  Employee_Salary Employment_Status  \
# 222544       British Virgin Islands         271140.0         Full Time
# 26453                         Gabon         678800.0            Intern
# 141265                      Morocco         816320.0         Full Time
# 184624                        Nauru         498850.0         Full Time
# 70533                      Bulgaria         332780.0         Full Time
# ...                             ...              ...               ...
# 50012                          Iran         986490.0            Intern
# 289392  French Southern Territories         712720.0         Full Time
# 14752                       Moldova         557330.0         Full Time
# 204854                    Swaziland         744300.0            Intern
# 242616                        Macao         704700.0            Intern
#
#         Employee_Rating
# 222544              5.0
# 26453               5.0
# 141265              5.0
# 184624              5.0
# 70533               5.0
# ...                 ...
# 50012               0.0
# 289392              0.0
# 14752               0.0
# 204854              0.0
# 242616              0.0
#
# [300000 rows x 8 columns]

# %% [markdown]
# ### 73. Print the name of 100th employee after sorting on Name

# %%
df.sort_values('Name', ascending=True).loc[100]
# Out:
# Name                                      Tracy Maxwell
# Company_Name                               Matthews Inc
# Employee_Job_Title    Sales promotion account executive
# Employee_City                            New Russellton
# Employee_Country                                   Oman
# Employee_Salary                                742410.0
# Employment_Status                             Full Time
# Employee_Rating                                     0.5
# Name: 100, dtype: object

# %% [markdown]
# ### 74. Print the first 5 rows of the first 5 columns.

# %%
df.iloc[0:5,0:5]
# Out:
#              Name                  Company_Name  \
# 0  Spencer Adkins                James and Sons
# 1    Julie Morton                 Nichols-James
# 2    Matthew Hall                     Scott Inc
# 3      Brad Scott  Johnston, Fleming and Tanner
# 4   Theresa Owens      Baker, Allen and Edwards
#
#                         Employee_Job_Title      Employee_City  \
# 0                          Equities trader     New Russellton
# 1  Diplomatic Services operational officer  North Melissafurt
# 2               Regulatory affairs officer           Wardfort
# 3                      Production engineer     West Jamesview
# 4                      Production engineer          Whiteside
#
#         Employee_Country
# 0  Palestinian Territory
# 1       Marshall Islands
# 2               Anguilla
# 3   Syrian Arab Republic
# 4               Dominica

# %% [markdown]
# ### 75. Print the transpose of the first 5 rows

# %%
df.iloc[0:5].transpose()
# Out:
#                                         0  \
# Name                       Spencer Adkins
# Company_Name               James and Sons
# Employee_Job_Title        Equities trader
# Employee_City              New Russellton
# Employee_Country    Palestinian Territory
# Employee_Salary                  321520.0
# Employment_Status               Full Time
# Employee_Rating                       3.9
#
#                                                           1  \
# Name                                           Julie Morton
# Company_Name                                  Nichols-James
# Employee_Job_Title  Diplomatic Services operational officer
# Employee_City                             North Melissafurt
# Employee_Country                           Marshall Islands
# Employee_Salary                                    589090.0
# Employment_Status                                 Full Time
# Employee_Rating                                         4.3
#
#                                              2                             3  \
# Name                              Matthew Hall                    Brad Scott
# Company_Name                         Scott Inc  Johnston, Fleming and Tanner
# Employee_Job_Title  Regulatory affairs officer           Production engineer
# Employee_City                         Wardfort                West Jamesview
# Employee_Country                      Anguilla          Syrian Arab Republic
# Employee_Salary                       630890.0                      116400.0
# Employment_Status                    Full Time                     Full Time
# Employee_Rating                            3.1                           3.1
#
#                                            4
# Name                           Theresa Owens
# Company_Name        Baker, Allen and Edwards
# Employee_Job_Title       Production engineer
# Employee_City                      Whiteside
# Employee_Country                    Dominica
# Employee_Salary                     523499.0
# Employment_Status                  Full Time
# Employee_Rating                          4.8

# %% [markdown]
# ### 76. Print the number of employees whose first name starts with the letter 'V'.

# %%
df[df['Name'].str.startswith('V')]['Name']
# Out:
# 5            Vanessa Allen
# 7              Vicki Beard
# 10         Victoria Sutton
# 38           Victor Miller
# 136        Victor Sandoval
#                 ...
# 299730      Valerie Graham
# 299750      Valerie Martin
# 299886     Victoria Garcia
# 299898      Vincent Werner
# 299907    Vicki Stephenson
# Name: Name, Length: 3683, dtype: object

# %%
df[df['Name'].str.startswith('V')]['Name'].count()
# Out:
# 3683

# %% [markdown]
# ### 77. Print the number of employees whose last name starts with the letter 'R'.

# %%
last_names=df['Name'].str.split().str[-1]

# %%
df[df['Name'].str.split().str[-1].str.startswith('R')]['Name']
# Out:
# 17                Gail Rose
# 26          Donna Rodriguez
# 28             Kim Reynolds
# 39            Jessica Reyes
# 55              Amanda Roth
#                 ...
# 299902    Michelle Reynolds
# 299905         Sandra Riley
# 299964     Joshua Rodriguez
# 299967         James Rhodes
# 299991    William Rodriguez
# Name: Name, Length: 20712, dtype: object

# %%
df[df['Name'].str.split().str[-1].str.startswith('R')]['Name'].count()
# Out:
# 20712

# %% [markdown]
# ### 78. Select the rows 2 to 7 and the columns 3 to 7 (both included)

# %%
df.iloc[2:8,3:8]
# Out:
#     Employee_City      Employee_Country  Employee_Salary Employment_Status  \
# 2        Wardfort              Anguilla         630890.0         Full Time
# 3  West Jamesview  Syrian Arab Republic         116400.0         Full Time
# 4       Whiteside              Dominica         523499.0         Full Time
# 5    Ricardomouth                  Mali         850140.0         Full Time
# 6        Wardfort                 Aruba         711410.0         Full Time
# 7     Kristaburgh        Western Sahara         777000.0         Full Time
#
#    Employee_Rating
# 2              3.1
# 3              3.1
# 4              4.8
# 5              2.6
# 6              2.0
# 7              3.3

# %% [markdown]
# ### 79. Select every row after the 10th row and select all columns.

# %%
df.iloc[10:,:]
# Out:
#                    Name                    Company_Name  \
# 10      Victoria Sutton         White, Mcclain and Cobb
# 11      Timothy Johnson        Baker, Allen and Edwards
# 12       Tiffany Galvan  Campos, Reynolds and Mccormick
# 13          David Duran                   Nichols-James
# 14           Julie Cook                    Matthews Inc
# ...                 ...                             ...
# 299995       Nancy Neal                Bullock-Carrillo
# 299996   Michele Butler    Johnston, Fleming and Tanner
# 299997      Lynn Wilson                   Nichols-James
# 299998    Lindsey Keith                   Nichols-James
# 299999    Karen Delgado                  James and Sons
#
#                              Employee_Job_Title      Employee_City  \
# 10                              Naval architect          Whiteside
# 11                   Regulatory affairs officer       Ricardomouth
# 12      Diplomatic Services operational officer     West Jamesview
# 13                 Investment banker, corporate     New Russellton
# 14                              Equities trader     New Russellton
# ...                                         ...                ...
# 299995                              Optometrist  North Melissafurt
# 299996                            Administrator         Aliciafort
# 299997                            Administrator   New Cindychester
# 299998                                     Make       Whitakerbury
# 299999                                  Actuary     New Russellton
#
#        Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 10               Poland         656260.0         Full Time              4.9
# 11              Georgia         503610.0         Full Time              2.9
# 12                Niger         786430.0            Intern              3.6
# 13              Georgia         910210.0         Full Time              4.9
# 14          Puerto Rico         328860.0         Full Time              4.8
# ...                 ...              ...               ...              ...
# 299995            Samoa          99670.0            Intern              3.3
# 299996             Cuba         949580.0            Intern              2.6
# 299997          Bolivia         802830.0         Full Time              0.6
# 299998   Western Sahara         257240.0         Full Time              2.4
# 299999   United Kingdom         575770.0            Intern              3.3
#
# [299990 rows x 8 columns]

# %% [markdown]
# ### 80. Select every row up to the 10th row and select all columns.

# %%
df.iloc[:11,:]
# Out:
#                Name                    Company_Name  \
# 0    Spencer Adkins                  James and Sons
# 1      Julie Morton                   Nichols-James
# 2      Matthew Hall                       Scott Inc
# 3        Brad Scott    Johnston, Fleming and Tanner
# 4     Theresa Owens        Baker, Allen and Edwards
# 5     Vanessa Allen                     Andrade LLC
# 6       Kelly Brown                     Andrade LLC
# 7       Vicki Beard                    Matthews Inc
# 8       Lisa French                    Taylor-Ramos
# 9   Michael Edwards  Campos, Reynolds and Mccormick
# 10  Victoria Sutton         White, Mcclain and Cobb
#
#                          Employee_Job_Title      Employee_City  \
# 0                           Equities trader     New Russellton
# 1   Diplomatic Services operational officer  North Melissafurt
# 2                Regulatory affairs officer           Wardfort
# 3                       Production engineer     West Jamesview
# 4                       Production engineer          Whiteside
# 5                                      Make       Ricardomouth
# 6                           Naval architect           Wardfort
# 7   Diplomatic Services operational officer        Kristaburgh
# 8                 Radiographer, therapeutic     West Jamesview
# 9                                Ergonomist   New Cindychester
# 10                          Naval architect          Whiteside
#
#                     Employee_Country  Employee_Salary Employment_Status  \
# 0              Palestinian Territory         321520.0         Full Time
# 1                   Marshall Islands         589090.0         Full Time
# 2                           Anguilla         630890.0         Full Time
# 3               Syrian Arab Republic         116400.0         Full Time
# 4                           Dominica         523499.0         Full Time
# 5                               Mali         850140.0         Full Time
# 6                              Aruba         711410.0         Full Time
# 7                     Western Sahara         777000.0         Full Time
# 8                             Kuwait         870580.0         Full Time
# 9   Lao People's Democratic Republic         516950.0         Full Time
# 10                            Poland         656260.0         Full Time
#
#     Employee_Rating
# 0               3.9
# 1               4.3
# 2               3.1
# 3               3.1
# 4               4.8
# 5               2.6
# 6               2.0
# 7               3.3
# 8               1.3
# 9               2.3
# 10              4.9

# %% [markdown]
# ### 81. Select rows with employee rating > 4.5.

# %%
rating = df['Employee_Rating']>4.5
df.loc[rating, 'Employee_Rating']
# Out:
# 4         4.8
# 10        4.9
# 13        4.9
# 14        4.8
# 49        4.7
#          ...
# 299910    4.7
# 299952    4.9
# 299957    4.8
# 299973    5.0
# 299981    4.8
# Name: Employee_Rating, Length: 26978, dtype: float64

# %%
df[df['Employee_Rating']>4.5]
# Out:
#                    Name              Company_Name  \
# 4         Theresa Owens  Baker, Allen and Edwards
# 10      Victoria Sutton   White, Mcclain and Cobb
# 13          David Duran             Nichols-James
# 14           Julie Cook              Matthews Inc
# 49      Gerald Santiago            Thomas-Spencer
# ...                 ...                       ...
# 299910   Daniel Johnson  Baker, Allen and Edwards
# 299952    Joshua Knight             Nichols-James
# 299957  Martha Phillips              Matthews Inc
# 299973     Doris Miller               Andrade LLC
# 299981   Herbert Bailey             Nichols-James
#
#                                        Employee_Job_Title     Employee_City  \
# 4                                     Production engineer         Whiteside
# 10                                        Naval architect         Whiteside
# 13                           Investment banker, corporate    New Russellton
# 14                                        Equities trader    New Russellton
# 49                           Garment/textile technologist       Kristaburgh
# ...                                                   ...               ...
# 299910                                     Energy manager          Wardfort
# 299952                  Sales promotion account executive          Wardfort
# 299957                                    Naval architect          Wardfort
# 299973  Armed forces logistics/support/administrative ...          Wardfort
# 299981                          Radiographer, therapeutic  New Cindychester
#
#        Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 4              Dominica         523499.0         Full Time              4.8
# 10               Poland         656260.0         Full Time              4.9
# 13              Georgia         910210.0         Full Time              4.9
# 14          Puerto Rico         328860.0         Full Time              4.8
# 49          El Salvador         873320.0         Full Time              4.7
# ...                 ...              ...               ...              ...
# 299910   American Samoa         452970.0         Full Time              4.7
# 299952             Mali         175450.0            Intern              4.9
# 299957          Somalia         485270.0         Full Time              4.8
# 299973       Kazakhstan         943340.0            Intern              5.0
# 299981         Guernsey         165550.0         Full Time              4.8
#
# [26978 rows x 8 columns]

# %% [markdown]
# ### 82. Select rows with employee rating > 4.5 and < 4.8.

# %%
df[(df['Employee_Rating']>4.5)& (df['Employee_Rating']>4.8)]
# Out:
#                     Name              Company_Name  \
# 10       Victoria Sutton   White, Mcclain and Cobb
# 13           David Duran             Nichols-James
# 66         Chad Guerrero  Baker, Allen and Edwards
# 114       Jeremiah Kelly                 Scott Inc
# 124       Joshua Huffman            James and Sons
# ...                  ...                       ...
# 299855  Rebecca Garrison                 Nelson-Li
# 299900      Daniel Jones              Taylor-Ramos
# 299906     Justin Mendez          Bullock-Carrillo
# 299952     Joshua Knight             Nichols-James
# 299973      Doris Miller               Andrade LLC
#
#                                        Employee_Job_Title     Employee_City  \
# 10                                        Naval architect         Whiteside
# 13                           Investment banker, corporate    New Russellton
# 66                                             Ergonomist        Aliciafort
# 114                                                  Make    West Jamesview
# 124                          Garment/textile technologist    New Russellton
# ...                                                   ...               ...
# 299855                                Production engineer      Whitakerbury
# 299900                  Sales promotion account executive       Kristaburgh
# 299906                         Regulatory affairs officer  New Cindychester
# 299952                  Sales promotion account executive          Wardfort
# 299973  Armed forces logistics/support/administrative ...          Wardfort
#
#        Employee_Country  Employee_Salary Employment_Status  Employee_Rating
# 10               Poland         656260.0         Full Time              4.9
# 13              Georgia         910210.0         Full Time              4.9
# 66                Congo         134810.0         Full Time              4.9
# 114            Anguilla         155360.0            Intern              4.9
# 124        Cook Islands         694760.0         Full Time              5.0
# ...                 ...              ...               ...              ...
# 299855          Ireland         592530.0         Full Time              5.0
# 299900     Sierra Leone          32160.0         Full Time              5.0
# 299906         Colombia         374540.0         Full Time              5.0
# 299952             Mali         175450.0            Intern              4.9
# 299973       Kazakhstan         943340.0            Intern              5.0
#
# [8992 rows x 8 columns]

# %% [markdown]
# ### 83. Print the name of the company with the maximum employees having rating > 4.

# %%
df[df['Employee_Rating']>4]['Company_Name'].value_counts().head(1)
# Out:
# Matthews Inc    3922
# Name: Company_Name, dtype: int64

# %% [markdown]
# ### 84. Print the rating of the employee named 'Julie Morton'.

# %%
df[df['Name']=="Julie Morton"]['Employee_Rating']
# Out:
# 1    4.3
# Name: Employee_Rating, dtype: float64

# %% [markdown]
# ### 85. Print the last 3rd entry in the column Employee_City

# %%
df.Employee_City.iloc[-3]
# Out:
# 'New Cindychester'

# %% [markdown]
# ### 86. Print the Employee_City column as a list

# %%
list(df['Employee_City'])
# Out:
# ['New Russellton',
#  'North Melissafurt',
#  'Wardfort',
#  'West Jamesview',
#  'Whiteside',
#  'Ricardomouth',
#  'Wardfort',
#  'Kristaburgh',
#  'West Jamesview',
#  'New Cindychester',
#  'Whiteside',
#  'Ricardomouth',
#  'West Jamesview',
#  'New Russellton',
#  'New Russellton',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Whitakerbury',
#  'New Russellton',
#  'New Russellton',
#  'Aliciafort',
#  'Wardfort',
#  'Kristaburgh',
#  'Aliciafort',
#  'Wardfort',
#  'Kristaburgh',
#  'Whiteside',
#  'Wardfort',
#  'West Jamesview',
#  'West Jamesview',
#  'New Russellton',
#  'Wardfort',
#  'Aliciafort',
#  'North Melissafurt',
#  'West Jamesview',
#  'New Cindychester',
#  'Wardfort',
#  'New Russellton',
#  'New Russellton',
#  'Kristaburgh',
#  'Kristaburgh',
#  'West Jamesview',
#  'Ricardomouth',
#  'Whiteside',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Whiteside',
#  'Kristaburgh',
#  'Ricardomouth',
#  'New Russellton',
#  'Ricardomouth',
#  'Aliciafort',
#  'Aliciafort',
#  'North Melissafurt',
#  'Whiteside',
#  'Kristaburgh',
#  'North Melissafurt',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Whiteside',
#  'New Cindychester',
#  'Aliciafort',
#  'North Melissafurt',
#  'Aliciafort',
#  'Whiteside',
#  'Wardfort',
#  'Aliciafort',
#  'Wardfort',
#  'West Jamesview',
#  'New Cindychester',
#  'Aliciafort',
#  'Whiteside',
#  'Ricardomouth',
#  'Wardfort',
#  'New Cindychester',
#  'West Jamesview',
#  'Whiteside',
#  'Whitakerbury',
#  'New Cindychester',
#  'Wardfort',
#  'Kristaburgh',
#  'New Cindychester',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Wardfort',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Aliciafort',
#  'New Russellton',
#  'New Russellton',
#  'West Jamesview',
#  'New Russellton',
#  'West Jamesview',
#  'Wardfort',
#  'Whiteside',
#  'Whiteside',
#  'New Russellton',
#  'Kristaburgh',
#  'Kristaburgh',
#  'West Jamesview',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'New Russellton',
#  'Whitakerbury',
#  'Ricardomouth',
#  'West Jamesview',
#  'New Cindychester',
#  'Whitakerbury',
#  'Whitakerbury',
#  'West Jamesview',
#  'New Russellton',
#  'New Cindychester',
#  'Aliciafort',
#  'West Jamesview',
#  'Aliciafort',
#  'Whiteside',
#  'West Jamesview',
#  'North Melissafurt',
#  'Whitakerbury',
#  'New Russellton',
#  'West Jamesview',
#  'Wardfort',
#  'Whiteside',
#  'Whitakerbury',
#  'Kristaburgh',
#  'New Cindychester',
#  'North Melissafurt',
#  'Aliciafort',
#  'Whiteside',
#  'Wardfort',
#  'Whitakerbury',
#  'Kristaburgh',
#  'New Cindychester',
#  'New Russellton',
#  'Kristaburgh',
#  'Whitakerbury',
#  'New Cindychester',
#  'Whitakerbury',
#  'West Jamesview',
#  'Whitakerbury',
#  'Wardfort',
#  'North Melissafurt',
#  'West Jamesview',
#  'Whitakerbury',
#  'West Jamesview',
#  'Ricardomouth',
#  'Aliciafort',
#  'Whitakerbury',
#  'Whiteside',
#  'Whiteside',
#  'West Jamesview',
#  'North Melissafurt',
#  'West Jamesview',
#  'Aliciafort',
#  'Whiteside',
#  'New Russellton',
#  'Whitakerbury',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Kristaburgh',
#  'West Jamesview',
#  'Kristaburgh',
#  'Wardfort',
#  'New Russellton',
#  'West Jamesview',
#  'Whitakerbury',
#  'Aliciafort',
#  'New Cindychester',
#  'New Cindychester',
#  'Whiteside',
#  'Ricardomouth',
#  'New Cindychester',
#  'New Cindychester',
#  'Aliciafort',
#  'Kristaburgh',
#  'New Cindychester',
#  'North Melissafurt',
#  'Wardfort',
#  'Wardfort',
#  'Kristaburgh',
#  'New Cindychester',
#  'Wardfort',
#  'West Jamesview',
#  'North Melissafurt',
#  'Whiteside',
#  'New Russellton',
#  'New Russellton',
#  'Kristaburgh',
#  'Whiteside',
#  'New Cindychester',
#  'North Melissafurt',
#  'Whitakerbury',
#  'West Jamesview',
#  'Whiteside',
#  'Whiteside',
#  'Whitakerbury',
#  'New Russellton',
#  'Kristaburgh',
#  'Kristaburgh',
#  'West Jamesview',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Kristaburgh',
#  'West Jamesview',
#  'Whiteside',
#  'North Melissafurt',
#  'New Cindychester',
#  'Wardfort',
#  'New Cindychester',
#  'Aliciafort',
#  'Kristaburgh',
#  'Aliciafort',
#  'Wardfort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'West Jamesview',
#  'Ricardomouth',
#  'Aliciafort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Whiteside',
#  'Kristaburgh',
#  'North Melissafurt',
#  'New Russellton',
#  'Ricardomouth',
#  'New Russellton',
#  'New Russellton',
#  'North Melissafurt',
#  'New Russellton',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Kristaburgh',
#  'New Cindychester',
#  'Wardfort',
#  'Ricardomouth',
#  'Aliciafort',
#  'New Cindychester',
#  'Kristaburgh',
#  'Wardfort',
#  'Wardfort',
#  'Aliciafort',
#  'Ricardomouth',
#  'Ricardomouth',
#  'New Russellton',
#  'New Russellton',
#  'Aliciafort',
#  'North Melissafurt',
#  'West Jamesview',
#  'Whiteside',
#  'Ricardomouth',
#  'West Jamesview',
#  'West Jamesview',
#  'West Jamesview',
#  'Whitakerbury',
#  'New Cindychester',
#  'New Russellton',
#  'Whitakerbury',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Kristaburgh',
#  'North Melissafurt',
#  'New Russellton',
#  'Aliciafort',
#  'North Melissafurt',
#  'Aliciafort',
#  'Whiteside',
#  'New Russellton',
#  'Kristaburgh',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Wardfort',
#  'New Russellton',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Aliciafort',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Whiteside',
#  'Aliciafort',
#  'Whitakerbury',
#  'New Cindychester',
#  'Whiteside',
#  'New Russellton',
#  'Whiteside',
#  'Ricardomouth',
#  'West Jamesview',
#  'New Russellton',
#  'West Jamesview',
#  'Whiteside',
#  'Ricardomouth',
#  'West Jamesview',
#  'Whiteside',
#  'Aliciafort',
#  'New Russellton',
#  'Kristaburgh',
#  'Wardfort',
#  'Wardfort',
#  'Whiteside',
#  'Whiteside',
#  'Whitakerbury',
#  'West Jamesview',
#  'Whitakerbury',
#  'New Cindychester',
#  'New Russellton',
#  'New Russellton',
#  'Ricardomouth',
#  'New Cindychester',
#  'Aliciafort',
#  'Whiteside',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Ricardomouth',
#  'New Cindychester',
#  'Wardfort',
#  'New Cindychester',
#  'Whiteside',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Aliciafort',
#  'Aliciafort',
#  'Whitakerbury',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Aliciafort',
#  'Aliciafort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Aliciafort',
#  'Whitakerbury',
#  'West Jamesview',
#  'New Russellton',
#  'Ricardomouth',
#  'North Melissafurt',
#  'West Jamesview',
#  'Aliciafort',
#  'New Cindychester',
#  'Whitakerbury',
#  'Ricardomouth',
#  'New Russellton',
#  'Aliciafort',
#  'West Jamesview',
#  'New Cindychester',
#  'Ricardomouth',
#  'Aliciafort',
#  'Wardfort',
#  'Whiteside',
#  'Ricardomouth',
#  'Wardfort',
#  'New Cindychester',
#  'Wardfort',
#  'Wardfort',
#  'New Russellton',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'New Cindychester',
#  'Whiteside',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Ricardomouth',
#  'New Cindychester',
#  'Whitakerbury',
#  'New Cindychester',
#  'New Russellton',
#  'Whiteside',
#  'New Russellton',
#  'West Jamesview',
#  'North Melissafurt',
#  'Aliciafort',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Wardfort',
#  'North Melissafurt',
#  'North Melissafurt',
#  'West Jamesview',
#  'West Jamesview',
#  'Whiteside',
#  'New Cindychester',
#  'West Jamesview',
#  'Wardfort',
#  'Whiteside',
#  'Whiteside',
#  'New Cindychester',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Whiteside',
#  'Whitakerbury',
#  'Kristaburgh',
#  'New Cindychester',
#  'Aliciafort',
#  'Aliciafort',
#  'Wardfort',
#  'Whiteside',
#  'Whitakerbury',
#  'North Melissafurt',
#  'West Jamesview',
#  'Wardfort',
#  'West Jamesview',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Wardfort',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Wardfort',
#  'Kristaburgh',
#  'New Cindychester',
#  'West Jamesview',
#  'Aliciafort',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Whiteside',
#  'North Melissafurt',
#  'Wardfort',
#  'Kristaburgh',
#  'New Russellton',
#  'Wardfort',
#  'Whitakerbury',
#  'New Cindychester',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Aliciafort',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Whiteside',
#  'New Cindychester',
#  'Whitakerbury',
#  'North Melissafurt',
#  'New Russellton',
#  'Aliciafort',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Whiteside',
#  'Ricardomouth',
#  'Aliciafort',
#  'Whitakerbury',
#  'Wardfort',
#  'North Melissafurt',
#  'Wardfort',
#  'Ricardomouth',
#  'Wardfort',
#  'Whiteside',
#  'New Russellton',
#  'Whiteside',
#  'New Cindychester',
#  'Whiteside',
#  'Whitakerbury',
#  'Ricardomouth',
#  'New Cindychester',
#  'Wardfort',
#  'New Russellton',
#  'New Cindychester',
#  'New Cindychester',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'Ricardomouth',
#  'West Jamesview',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Whiteside',
#  'West Jamesview',
#  'New Cindychester',
#  'Whitakerbury',
#  'Wardfort',
#  'Kristaburgh',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Wardfort',
#  'North Melissafurt',
#  'Kristaburgh',
#  'West Jamesview',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Aliciafort',
#  'New Russellton',
#  'New Russellton',
#  'Aliciafort',
#  'Ricardomouth',
#  'Whiteside',
#  'Aliciafort',
#  'New Russellton',
#  'Whitakerbury',
#  'New Russellton',
#  'Aliciafort',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Whiteside',
#  'Whiteside',
#  'Whiteside',
#  'New Russellton',
#  'Whiteside',
#  'West Jamesview',
#  'Wardfort',
#  'Whitakerbury',
#  'Wardfort',
#  'Whiteside',
#  'Whiteside',
#  'Whiteside',
#  'New Cindychester',
#  'Whiteside',
#  'Kristaburgh',
#  'New Russellton',
#  'Wardfort',
#  'Ricardomouth',
#  'New Cindychester',
#  'Ricardomouth',
#  'Whiteside',
#  'North Melissafurt',
#  'North Melissafurt',
#  'New Cindychester',
#  'West Jamesview',
#  'New Russellton',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Aliciafort',
#  'New Cindychester',
#  'New Russellton',
#  'North Melissafurt',
#  'North Melissafurt',
#  'North Melissafurt',
#  'Kristaburgh',
#  'New Russellton',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Wardfort',
#  'Wardfort',
#  'Wardfort',
#  'Ricardomouth',
#  'West Jamesview',
#  'Whiteside',
#  'Aliciafort',
#  'Whitakerbury',
#  'Aliciafort',
#  'Ricardomouth',
#  'Whitakerbury',
#  'Whiteside',
#  'New Russellton',
#  'Whiteside',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Aliciafort',
#  'New Russellton',
#  'New Cindychester',
#  'Aliciafort',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Ricardomouth',
#  'New Cindychester',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Wardfort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Aliciafort',
#  'New Russellton',
#  'West Jamesview',
#  'New Cindychester',
#  'Wardfort',
#  'Whitakerbury',
#  'Aliciafort',
#  'Wardfort',
#  'Aliciafort',
#  'Wardfort',
#  'North Melissafurt',
#  'Wardfort',
#  'Whiteside',
#  'Ricardomouth',
#  'Wardfort',
#  'New Russellton',
#  'New Cindychester',
#  'Whiteside',
#  'Whiteside',
#  'Whiteside',
#  'New Cindychester',
#  'Aliciafort',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Kristaburgh',
#  'West Jamesview',
#  'New Russellton',
#  'North Melissafurt',
#  'New Russellton',
#  'New Russellton',
#  'Kristaburgh',
#  'Aliciafort',
#  'Whiteside',
#  'Wardfort',
#  'Whiteside',
#  'Kristaburgh',
#  'Aliciafort',
#  'Aliciafort',
#  'Aliciafort',
#  'Wardfort',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Ricardomouth',
#  'New Russellton',
#  'New Russellton',
#  'Wardfort',
#  'New Cindychester',
#  'North Melissafurt',
#  'Ricardomouth',
#  'Wardfort',
#  'Whitakerbury',
#  'Aliciafort',
#  'New Cindychester',
#  'Ricardomouth',
#  'New Russellton',
#  'Wardfort',
#  'Whiteside',
#  'Ricardomouth',
#  'Aliciafort',
#  'Aliciafort',
#  'Ricardomouth',
#  'New Cindychester',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Wardfort',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Wardfort',
#  'Whiteside',
#  'North Melissafurt',
#  'Aliciafort',
#  'Whiteside',
#  'Whitakerbury',
#  'Aliciafort',
#  'North Melissafurt',
#  'New Cindychester',
#  'New Russellton',
#  'North Melissafurt',
#  'New Cindychester',
#  'New Russellton',
#  'New Russellton',
#  'Whiteside',
#  'New Cindychester',
#  'Whitakerbury',
#  'Wardfort',
#  'Ricardomouth',
#  'New Cindychester',
#  'New Russellton',
#  'Whiteside',
#  'Ricardomouth',
#  'New Cindychester',
#  'New Russellton',
#  'West Jamesview',
#  'Kristaburgh',
#  'West Jamesview',
#  'Wardfort',
#  'West Jamesview',
#  'New Cindychester',
#  'North Melissafurt',
#  'Aliciafort',
#  'North Melissafurt',
#  'New Cindychester',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'Whitakerbury',
#  'West Jamesview',
#  'New Russellton',
#  'Whitakerbury',
#  'Kristaburgh',
#  'West Jamesview',
#  'Whitakerbury',
#  'Whiteside',
#  'New Cindychester',
#  'Ricardomouth',
#  'Whitakerbury',
#  'Wardfort',
#  'New Cindychester',
#  'Kristaburgh',
#  'Wardfort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Kristaburgh',
#  'New Cindychester',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Ricardomouth',
#  'New Cindychester',
#  'New Russellton',
#  'New Cindychester',
#  'Whiteside',
#  'Ricardomouth',
#  'New Cindychester',
#  'Ricardomouth',
#  'Whitakerbury',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Wardfort',
#  'Whitakerbury',
#  'Wardfort',
#  'West Jamesview',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Ricardomouth',
#  'Whitakerbury',
#  'Wardfort',
#  'New Russellton',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Whiteside',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Wardfort',
#  'Kristaburgh',
#  'West Jamesview',
#  'Wardfort',
#  'West Jamesview',
#  'Wardfort',
#  'Aliciafort',
#  'Whiteside',
#  'West Jamesview',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Aliciafort',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Whitakerbury',
#  'Whitakerbury',
#  'New Cindychester',
#  'Whitakerbury',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Aliciafort',
#  'Wardfort',
#  'Aliciafort',
#  'North Melissafurt',
#  'West Jamesview',
#  'Aliciafort',
#  'Aliciafort',
#  'West Jamesview',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Wardfort',
#  'Whiteside',
#  'Wardfort',
#  'West Jamesview',
#  'Whiteside',
#  'New Russellton',
#  'West Jamesview',
#  'Ricardomouth',
#  'Ricardomouth',
#  'North Melissafurt',
#  'New Cindychester',
#  'Aliciafort',
#  'North Melissafurt',
#  'New Russellton',
#  'West Jamesview',
#  'New Cindychester',
#  'North Melissafurt',
#  'West Jamesview',
#  'New Russellton',
#  'Wardfort',
#  'West Jamesview',
#  'Wardfort',
#  'New Russellton',
#  'Ricardomouth',
#  'West Jamesview',
#  'West Jamesview',
#  'New Cindychester',
#  'Aliciafort',
#  'West Jamesview',
#  'Wardfort',
#  'Whiteside',
#  'West Jamesview',
#  'Whiteside',
#  'New Russellton',
#  'New Cindychester',
#  'New Cindychester',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Wardfort',
#  'New Russellton',
#  'Wardfort',
#  'Ricardomouth',
#  'New Cindychester',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Ricardomouth',
#  'Whiteside',
#  'Ricardomouth',
#  'Whiteside',
#  'North Melissafurt',
#  'Whiteside',
#  'Ricardomouth',
#  'North Melissafurt',
#  'West Jamesview',
#  'New Russellton',
#  'North Melissafurt',
#  'Kristaburgh',
#  'West Jamesview',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Ricardomouth',
#  'New Russellton',
#  'New Cindychester',
#  'New Cindychester',
#  'Whitakerbury',
#  'New Cindychester',
#  'Ricardomouth',
#  'West Jamesview',
#  'Ricardomouth',
#  'New Russellton',
#  'Ricardomouth',
#  'Wardfort',
#  'Ricardomouth',
#  'Aliciafort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Wardfort',
#  'New Cindychester',
#  'Aliciafort',
#  'New Cindychester',
#  'New Cindychester',
#  'Whiteside',
#  'West Jamesview',
#  'Aliciafort',
#  'New Russellton',
#  'Kristaburgh',
#  'Aliciafort',
#  'Whiteside',
#  'Whitakerbury',
#  'North Melissafurt',
#  'West Jamesview',
#  'New Russellton',
#  'Ricardomouth',
#  'Aliciafort',
#  'Whitakerbury',
#  'New Cindychester',
#  'West Jamesview',
#  'New Russellton',
#  'New Cindychester',
#  'New Russellton',
#  'North Melissafurt',
#  'West Jamesview',
#  'Ricardomouth',
#  'West Jamesview',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Wardfort',
#  'Wardfort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Whitakerbury',
#  'New Cindychester',
#  'Whitakerbury',
#  'New Russellton',
#  'New Russellton',
#  'Wardfort',
#  'New Cindychester',
#  'North Melissafurt',
#  'Wardfort',
#  'Ricardomouth',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Aliciafort',
#  'Whiteside',
#  'Whitakerbury',
#  'Ricardomouth',
#  'Ricardomouth',
#  'Ricardomouth',
#  'North Melissafurt',
#  'Ricardomouth',
#  'West Jamesview',
#  'Wardfort',
#  'Wardfort',
#  'New Cindychester',
#  'North Melissafurt',
#  'North Melissafurt',
#  'New Cindychester',
#  'Whiteside',
#  'North Melissafurt',
#  'West Jamesview',
#  'New Russellton',
#  'New Russellton',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'Whitakerbury',
#  'Whiteside',
#  'Aliciafort',
#  'Ricardomouth',
#  'Ricardomouth',
#  'New Russellton',
#  'Whitakerbury',
#  'Whiteside',
#  'Whiteside',
#  'Whiteside',
#  'Kristaburgh',
#  'Wardfort',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Whiteside',
#  'New Cindychester',
#  'New Russellton',
#  'North Melissafurt',
#  'New Russellton',
#  'Wardfort',
#  'New Cindychester',
#  'Kristaburgh',
#  'Wardfort',
#  'Kristaburgh',
#  'North Melissafurt',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Wardfort',
#  'Whiteside',
#  'Kristaburgh',
#  'Ricardomouth',
#  'Aliciafort',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Whitakerbury',
#  'Whitakerbury',
#  'Wardfort',
#  'Aliciafort',
#  'Ricardomouth',
#  'Kristaburgh',
#  'Wardfort',
#  'New Russellton',
#  'North Melissafurt',
#  'Wardfort',
#  'Kristaburgh',
#  'Kristaburgh',
#  'Whitakerbury',
#  'North Melissafurt',
#  'West Jamesview',
#  'Whitakerbury',
#  'Ricardomouth',
#  'Whitakerbury',
#  'Wardfort',
#  'North Melissafurt',
#  'Kristaburgh',
#  'Whiteside',
#  'New Cindychester',
#  'Ricardomouth',
#  'New Cindychester',
#  'Whitakerbury',
#  'Whiteside',
#  'Whiteside',
#  'New Russellton',
#  'Whiteside',
#  'Whiteside',
#  'Ricardomouth',
#  'New Russellton',
#  'New Cindychester',
#  'Kristaburgh',
#  'Aliciafort',
#  'New Russellton',
#  'Wardfort',
#  'New Russellton',
#  'Whitakerbury',
#  'Aliciafort',
#  'Kristaburgh',
#  ...]

# %% [markdown]
# ### 87. Are the number of employees in 'Scott Inc' company greater than that in 'Andrade LLC'? Print True/False

# %%
df[(df['Company_Name']=="Andrade LLC")]['Name'].count()
# Out:
# 19983

# %%
company_scott=df[(df['Company_Name']=="Scott Inc")]['Name'].count()
company_Andrade=df[(df['Company_Name']=="Andrade LLC")]['Name'].count()
if company_scott > company_Andrade:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 88. Which is the most common first name in the dataframe?

# %%
first_name=df['Name'].str.split().str[0]
first_name.value_counts().head(1)
# Out:
# Michael    6892
# Name: Name, dtype: int64

# %% [markdown]
# ### 89. Which is the least common last name in the dataframe?

# %%
last_name=df['Name'].str.split().str[-1]
last_name.value_counts().sort_values(ascending=True).head(1)
# Out:
# Bright    71
# Name: Name, dtype: int64

# %% [markdown]
# ### 90. What is the average name length?

# %%
df['Name'].str.len().mean()
# Out:
# 13.1079

# %% [markdown]
# Great job solving this notebook. Go to Pandas Notebook  3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/%2Fnotebook.ipynb)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a979431d-6bbb-43f7-8e12-adf738a4d0e0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
