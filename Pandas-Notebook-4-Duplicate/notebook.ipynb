# %% [markdown]
# # 450+ Practice Questions That Will Make You a Pandas, NumPy, and SQL Pro!

# %% [markdown]
# Author: Avi Chawla
#
# LinkedIn: https://www.linkedin.com/in/avi-chawla/
#
# Read my blogs here: https://medium.com/@avi_chawla

# %% [markdown]
# ## Introduction

# %% [markdown]
# This notebook has been created for you to practice three of the most common tools used in building any machine learning or data science applications, i.e., Pandas, NumPy, and SQL!

# %% [markdown]
# The practice questions provided will serve as a great resource for those who are looking to familiarize themselves with some of the most common functions used in these tools.

# %% [markdown]
# Appropriate descriptions have been provided for all the questions in this entire exercise which will help you navigate through this exercise easily. If a dataset is to be loaded in the python environment, that has also been provided for you. You can find it on the right panel in the Files section. Do NOT delete any of the files/folders listed there.

# %% [markdown]
# The whole exercise has been divided into nine separate notebooks. Below are the links to all the other notebooks for you to jump from one notebook to another:

# %% [markdown]
# - **Pandas**
#
# 1. Pandas Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-1-d693ac55-6455-40cf-ae34-867c6a02014e/%2Fnotebook.ipynb)
# 2. Pandas Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-dataset-7e3b6755-5d4b-464b-9b75-9c84667ae3bd/%2Fnotebook.ipynb)
#
# 3. Pandas Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-Notebook-employee-part-2-adc5a3ee-5f61-4725-8e46-ccb07899acfc/%2Fnotebook.ipynb)
#
# 4. Pandas Notebook 4: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Pandas-after-employee-f84e02a1-fb6a-428e-af90-8dd99855749a/%2Fnotebook.ipynb) **(This Notebook)**
#
# - **NumPy**
#
# 1. NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/%2Fnotebook.ipynb)
#
# 2. NumPy Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-2-4456411e-2ddd-426d-8027-4881080027db/%2Fnotebook.ipynb)
#
# 3. NumPy Notebook 3: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/NumPy-Notebook-3-e6587114-b580-4249-b599-540de859e603/%2Fnotebook.ipynb)
#
# - **SQL**
#
# 1. SQL Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-1-eac9d782-a9b1-4e84-a1f9-af14080a6121/%2Fnotebook.ipynb)
#
# 2. SQL Notebook 2: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/SQL-Notebook-2-1914b214-be03-44a1-be63-ad99e98be639/%2Fnotebook.ipynb)

# %% [markdown]
# ## How to use this notebook?

# %% [markdown]
# At the top right corner, you will find a Duplicate button. This will allow you to create a unique notebook for your own practice and write solutions to the question listed in this notebook.

# %% [markdown]
# If you face any issues or have any feedback, feel free to reach out to me (Avi Chawla) either on Linkedin: https://www.linkedin.com/in/avi-chawla/ or write an email to avi@dsscholar[dot]com.

# %% [markdown]
# Let's begin 🚀!

# %% [markdown]
# # Pandas Notebook 4

# %% [markdown]
# ### 151. Sort DataFrame based on another list

# %%
import pandas as pd

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], columns=["col1", "col2"])

sort_list = ["C", "A", "D", "B"]

## start your code below
new_df = df.set_index('col1').loc[sort_list].reset_index()
## end your code here

print(new_df)
# Out:
#   col1  col2
# 0    C     3
# 1    A     1
# 2    D     4
# 3    B     2

# %% [markdown]
# ### 152. Insert a column at a specific location in a DataFrame

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

new_column = ["P", "Q", "R", "S"]
insert_position = 1 ## between col_A and col_B

## start your code below
new_df = df.copy()
new_df.insert(insert_position, 'col_C',new_column)
## end your code here

print(new_df)
# Out:
#   col_A col_C  col_B
# 0     A     P      1
# 1     B     Q      2
# 2     C     R      3
# 3     D     S      4

# %% [markdown]
# ### 153. Select columns based on the column's Data Type

# %%
df = pd.DataFrame([["A", 1, True], ["B", 2, False],
                   ["C", 3, False], ["D", 4, True]], 
                  columns=["col_A", "col_B", "col_C"])

dt_type = "bool"

## start your code below
new_df = df.dtypes==dt_type
# new_df.dtypes=="bool"
## end your code here

print(new_df)
# Out:
# col_A    False
# col_B    False
# col_C     True
# dtype: bool

# %% [markdown]
# ### 154. Count the number of Non-NaN cells for each column

# %%
import numpy as np
df = pd.DataFrame([["A", np.NaN], [np.NaN, 2],
                   ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below

new_df = df.notnull().sum()
## end your code here

print(new_df)
# Out:
# col_A    3
# col_B    2
# dtype: int64

# %%
df
# Out:
#   col_A  col_B
# 0     A    NaN
# 1   NaN    2.0
# 2     C    NaN
# 3     D    4.0

# %% [markdown]
# ### 155. Split DataFrame into equal parts

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

parts = 2

## start your code below
new_df1, new_df2 = np.split(df,parts)
## end your code here

print(new_df1)
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2

# %%
print(new_df2)
# Out:
#   col_A  col_B
# 2     C      3
# 3     D      4

# %% [markdown]
# ### 156. Reverse DataFrame row-wise

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
row_reverse =df.iloc[::-1,:]
## end your code here

# %%
df
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4

# %%
row_reverse
# Out:
#   col_A  col_B
# 3     D      4
# 2     C      3
# 1     B      2
# 0     A      1

# %% [markdown]
# ### 157. Reverse DataFrame column-wise

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
col_reverse = df.iloc[:,::-1]
## end your code here

# %%
col_reverse
# Out:
#    col_B col_A
# 0      1     A
# 1      2     B
# 2      3     C
# 3      4     D

# %% [markdown]
# ### 158. Insert a row at an arbitrary position

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

insert_pos = 1
insert_row = ["P", 5]

## start your code below
new_df = df.copy()
new_df.loc[insert_pos] = insert_row

## end your code here

# %%
new_df
# Out:
#   col_A  col_B
# 0     A      1
# 1     P      5
# 2     C      3
# 3     D      4

# %% [markdown]
# ### 159. Apply function to every cell of DataFrame

# %%
df = pd.DataFrame([[1, 5], [2, 6],
                   [3, 7], [4, 8]], 
                  columns=["col_A", "col_B"])

def func(num):
    return num + 1

## start your code below
new_df = func(df)
## end your code here

print(new_df)
# Out:
#    col_A  col_B
# 0      2      6
# 1      3      7
# 2      4      8
# 3      5      9

# %% [markdown]
# ### 160. The cumulative sum of a column in DataFrame

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], columns=["col_A", "col_B"])

## start your code below
new_df = df.sum()
## end your code here

# %%
new_df
# Out:
# col_A    ABCD
# col_B      10
# dtype: object

# %% [markdown]
# ### 161. Uniquely number individual group in Pandas GroupBy

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], columns=["col_A", "col_B"])

## start your code below
new_df = df.groupby("col_A").ngroup()
## end your code here

# %%
new_df
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %% [markdown]
# ### 162. Check if column has NaN values

# %%
df = pd.DataFrame([["A", np.NaN], ["A", 2], ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
col_A_check = df['col_A'].isnull()
col_B_check = df['col_B'].isnull()
## end your code here

# %%
col_A_check, col_B_check
# Out:
# (0    False
#  1    False
#  2    False
#  3    False
#  Name: col_A, dtype: bool,
#  0     True
#  1    False
#  2     True
#  3    False
#  Name: col_B, dtype: bool)

# %% [markdown]
# ### 163. Append a list as a row to a DataFrame

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

new_row = ["E", 5]

## start your code below
# new_df = df.append(pd.Series(new_row, index=df.columns), ignore_index=True)
new_df = df.copy()
# new_df=new_df.append(new_row, ignore_index = True)
new_df.loc[len(new_df)] = new_row
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 2     C      3
# 3     D      4
# 4     E      5

# %% [markdown]
# ### 164. Identify the source of each row in Pandas Merge

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_A", "col_C"])

## start your code below
new_df = pd.merge(df1,df2, on="col_A", how="outer")
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C
# 0     A    1.0    3.0
# 1     B    2.0    NaN
# 2     C    NaN    4.0

# %% [markdown]
# ### 165. Filter n-largest values from a DataFrame

# %%
df = pd.DataFrame([["A", 200], ["B", 400],
                   ["C", 100], ["D", 300]], 
                  columns=["col_A", "col_B"])

k = 2

## start your code below
largest_k = df.nlargest(n=2, columns="col_B")
## end your code here

# %%
largest_k
# Out:
#   col_A  col_B
# 1     B    400

# %% [markdown]
# ### 166. Filter n-smallest values from a DataFrame

# %%
df = pd.DataFrame([["A", 200], ["B", 400],
                   ["C", 100], ["D", 300]], 
                  columns=["col_A", "col_B"])

k = 2

## start your code below
smallest_k =df.nsmallest(n=k, columns="col_B")
## end your code here

# %%
smallest_k
# Out:
#   col_A  col_B
# 2     C    100
# 0     A    200

# %% [markdown]
# ### 167. Map categorical data to unique integral values

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = df['col_A'].astype("category").cat.codes
## end your code here

print(new_df)
# Out:
# 0    0
# 1    1
# 2    0
# 3    2
# dtype: int8

# %% [markdown]
# ### 168. Add prefix to every column name

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = df.add_prefix("col_")
## end your code here

print(new_df)
# Out:
#   col_col_A  col_col_B
# 0         A          1
# 1         B          2
# 2         C          3
# 3         D          4

# %% [markdown]
# ### 169. Delete the rows that have NaN values

# %%
df = pd.DataFrame([["A", np.NaN], ["B", 2],
                   ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = df.dropna()
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 1     B    2.0
# 3     D    4.0

# %% [markdown]
# ### 170. Fill NaN values with 1

# %%
df = pd.DataFrame([["A", np.NaN], ["B", 2],
                   ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = df.fillna(value=1)
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A    1.0
# 1     B    2.0
# 2     C    1.0
# 3     D    4.0

# %% [markdown]
# ### 171. Fill NaN values with column mean

# %%
df = pd.DataFrame([["A", np.NaN], ["B", 2],
                   ["C", np.NaN], ["D", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
mean = df['col_B'].mean()
new_df = df.fillna(df.mean())
#or
#new_df = df.fillna(df.mean())
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A    3.0
# 1     B    2.0
# 2     C    3.0
# 3     D    4.0
# <ipython-input-51-3b948937ba6e>:7: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_df = df.fillna(df.mean())

# %% [markdown]
# ### 172. Fill NaN values with column mode

# %%
df = pd.DataFrame([["A", 1], [np.NaN, 2],
                   ["A", 3], [np.NaN, 4], 
                   ["B", 5], ["C", 6]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = df.fillna(df.mode().iloc[0])
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     A      2
# 2     A      3
# 3     A      4
# 4     B      5
# 5     C      6

# %% [markdown]
# ### 173. Swap two rows of a dataframe

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["C", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])

# swap second and last row
row_1, row_2 = 1, 3 

## start your code below
new_df = df.copy()
new_df.iloc[[1,3]] = new_df.iloc[[3,1]]
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     D      4
# 2     C      3
# 3     B      2

# %% [markdown]
# ### 174. Create a column "col4" that contains the 2nd largest value in each row

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 2, 9],
                   [2, 9, 3], 
                   [8, 5, 4]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.copy()
new_df['col_4']= new_df.apply(lambda row: sorted(row)[-2], axis=1)
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C  col_4
# 0      4      1      5      4
# 1      5      2      9      5
# 2      2      9      3      3
# 3      8      5      4      5

# %% [markdown]
# ### 175. Replace the values on the main diagonal of the dataframe with 0

# %%
df = pd.DataFrame([[4, 1, 5, 10], [5, 2, 9, 4],
                   [2, 9, 3, 1],  [1, 7, 3,10]], 
                  columns=["col_A", "col_B", "col_C", "col_D"])


## start your code below
new_df = df.copy()
for i in range(len(new_df)):
    new_df.iloc[i,i] = 0

## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C  col_D
# 0      0      1      5     10
# 1      5      0      9      4
# 2      2      9      0      1
# 3      1      7      3      0

# %% [markdown]
# ### 176. Get the Group "A" of the dataframe by first grouping the dataframe and then using the group key.

# %%
df = pd.DataFrame([["A", 1], ["B", 2],
                   ["A", 3], ["D", 4]], 
                  columns=["col_A", "col_B"])


## start your code below
new_df = df.groupby("col_A").get_group("A")
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 2     A      3

# %% [markdown]
# ### 177. Fetch the rows where the value in "col_C" does not belong to "col_B".

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 2, 9],
                   [2, 9, 3], 
                   [8, 5, 4]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
# df['col_C'].values
new_df =df[df['col_C'] != df['col_B']]
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 0      4      1      5
# 1      5      2      9
# 2      2      9      3
# 3      8      5      4

# %% [markdown]
# ### 178. Get the rows where the value of "col_A" is equal to "col_B".

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df[df['col_A'] == df['col_B']]
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 1      5      5      9

# %% [markdown]
# ### 179. Get the rows where (the value of "col_A" is equal to "col_B") OR (the value of "col_A" is equal to "col_C").

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df[(df['col_C'] == df['col_B']) | (df['col_A'] != df['col_C'])]
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 0      4      1      5
# 1      5      5      9
# 2      2      9      3

# %% [markdown]
# ### 180. Sort the Data on col_A and col_B

# %% [markdown]
# col_A -> Ascending
# col_B -> Ascending

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.sort_values(by=["col_A", "col_B"])
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 2      2      9      3
# 0      4      1      5
# 1      5      5      9
# 3      8      5      8

# %% [markdown]
# ### 181. Sort the Data on col_A and col_B

# %% [markdown]
# col_A -> Ascending
# col_B -> Descending

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.sort_values(by=["col_A", "col_B"], ascending=[True, False])
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 2      2      9      3
# 0      4      1      5
# 1      5      5      9
# 3      8      5      8

# %% [markdown]
# ### 182. Get the mean of every column

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
mean = df.mean()
## end your code here

print(mean)
# Out:
# col_A    4.75
# col_B    5.00
# col_C    6.25
# dtype: float64

# %% [markdown]
# ### 182. Get the mean of every row

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
mean = df.mean(axis=1)
## end your code here

print(mean)
# Out:
# 0    3.333333
# 1    6.333333
# 2    4.666667
# 3    7.000000
# dtype: float64

# %% [markdown]
# ### 183. Concatentate the two DataFrames row-wise

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_A", "col_B"])

## start your code below
new_df = pd.concat([df1,df2], axis=0 )
## end your code here

print(new_df)
# Out:
#   col_A  col_B
# 0     A      1
# 1     B      2
# 0     A      3
# 1     C      4

# %% [markdown]
# ### 184. Concatentate the two DataFrames column-wise

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_C", "col_D"])

## start your code below
new_df = pd.concat([df1,df2], axis=1 )
## end your code here

print(new_df)
# Out:
#   col_A  col_B col_C  col_D
# 0     A      1     A      3
# 1     B      2     C      4

# %% [markdown]
# ### 185. Change the last two values in the last column to [2,4]

# %% [markdown]
# Change 3 -> 2
# Change 8 -> 4
#
# **Note: You should do this in a single line of code**

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 9],
                   [2, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.copy()
new_df.loc[df.index[-2:], 'col_C'] = [2, 4]
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 0      4      1      5
# 1      5      5      9
# 2      2      9      2
# 3      8      5      4

# %% [markdown]
# ### 186. Replace all '1' with '2'

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.replace(1,2)
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 0      4      2      5
# 1      5      5      2
# 2      2      9      3
# 3      8      5      8

# %% [markdown]
# ### 187. Replace all '1' with '2' and '5' with '6' in a single line of code

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.replace({1:2,5:6})

## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C
# 0      4      2      6
# 1      6      6      2
# 2      2      9      3
# 3      8      6      8

# %% [markdown]
# ### 188. Sample 2 random rows from the DataFrame

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
sample_df = df.sample(2)
## end your code here

print(sample_df)
# Out:
#    col_A  col_B  col_C
# 1      5      5      1
# 0      4      1      5

# %% [markdown]
# ### 189. Convert the DataFrame to a list of lists. Don't include the header row.

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
data_list =df.values.tolist()[1:]
## end your code here

print(data_list)
# Out:
# [[5, 5, 1], [1, 9, 3], [8, 5, 8]]

# %% [markdown]
# ### 190. Add three new columns that show the cumulative sum of every column

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df['cumsum_A'] = df['col_A'].cumsum()
df['cumsum_B'] = df['col_B'].cumsum()
df['cumsum_C'] = df['col_C'].cumsum()
data_list = df.copy()
## end your code here

print(data_list)
# Out:
#    col_A  col_B  col_C  cumsum_A  cumsum_B  cumsum_C
# 0      4      1      5         4         1         5
# 1      5      5      1         9         6         6
# 2      1      9      3        10        15         9
# 3      8      5      8        18        20        17

# %% [markdown]
# ### 191. Print the cumulative sum of every row in a new column.

# %% [markdown]
# ### In other words, make a column that stores the cumulative sum of the (sum of every row).

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df['cumulative_sum'] = df.cumsum(axis=1).iloc[:, -1]
new_df = df.copy()
## end your code here

print(new_df)
# Out:
#    col_A  col_B  col_C  cumulative_sum
# 0      4      1      5              10
# 1      5      5      1              11
# 2      1      9      3              13
# 3      8      5      8              21

# %% [markdown]
# ### 192. Find the frequency of every element in col_A

# %%
df = pd.DataFrame([["A", 1, 5], 
                   ["B", 5, 1],
                   ["C", 9, 3], 
                   ["A", 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df['col_A'].value_counts()
## end your code here

print(new_df)
# Out:
# A    2
# B    1
# C    1
# Name: col_A, dtype: int64

# %% [markdown]
# ### 193. Normalize the frequency of every element in col_A

# %%
df = pd.DataFrame([["A", 1, 5], 
                   ["B", 5, 1],
                   ["C", 9, 3], 
                   ["A", 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
df['frequency'] = df.groupby('col_A')['col_A'].transform('count') / len(df)

new_df = df.copy()
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C  frequency
# 0     A      1      5       0.50
# 1     B      5      1       0.25
# 2     C      9      3       0.25
# 3     A      5      8       0.50

# %% [markdown]
# ### 194. GroupBy col_A, then find the sum of col_B and mean of col_C

# %%
df = pd.DataFrame([["A", 1, 5], 
                   ["B", 5, 1],
                   ["C", 9, 3], 
                   ["A", 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
# new_df = df.groupby('col_A')[df['col_B'].sum(), df['col_C'].mean()]
new_df = df.groupby('col_A').agg({'col_B':'sum', 'col_C':'mean'})
## end your code here

print(new_df)
# Out:
#        col_B  col_C
# col_A
# A          6    6.5
# B          5    1.0
# C          9    3.0

# %% [markdown]
# ### 195. Find the correlation between every pair of column

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df = df.corr()
## end your code here

print(new_df)
# Out:
#           col_A     col_B     col_C
# col_A  1.000000 -0.424264  0.599377
# col_B -0.424264  1.000000 -0.273434
# col_C  0.599377 -0.273434  1.000000

# %% [markdown]
# ### 196. GroupBy col_A, then compute a new column as (10*col_B/col_C)

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below


new_df = df.groupby('col_A').apply(lambda x: 10*x['col_B']/x['col_C'])
## end your code here

print(new_df)
# Out:
# col_A
# 1      2    30.00
# 4      0     2.00
# 5      1    50.00
# 8      3     6.25
# dtype: float64

# %% [markdown]
# ### 197. GroupBy col_A, then compute a new column as (10*col_B/col_C). Project the new column back to the original dataframe

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
new_df['NEW_COLUMN'] = df.groupby('col_A').apply(lambda x: 10*x['col_B']/x['col_C']).reset_index(drop=True)
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C  NEW_COLUMN
# 0     A    1.0    3.0        30.0
# 1     B    2.0    NaN         2.0
# 2     C    NaN    4.0        50.0

# %% [markdown]
# ### 198. Merge the two dataframes using the join() method on col_A.

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_A", "col_C"])

## start your code below
# new_df = df1.join(df2, on='col_A')
new_df = df1.set_index('col_A').join(df2.set_index('col_A'), how="outer").reset_index()
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C
# 0     A    1.0    3.0
# 1     B    2.0    NaN
# 2     C    NaN    4.0

# %% [markdown]
# ### 199. Perform the full outer join on the two DataFrames.

# %%
df1 = pd.DataFrame([["A", 1], ["B", 2]], 
                  columns=["col_A", "col_B"])

df2 = pd.DataFrame([["A", 3], ["C", 4]], 
                  columns=["col_A", "col_C"])

## start your code below
new_df = df1.merge(df2, on="col_A",how="outer")
## end your code here

print(new_df)
# Out:
#   col_A  col_B  col_C
# 0     A    1.0    3.0
# 1     B    2.0    NaN
# 2     C    NaN    4.0

# %% [markdown]
# ### 200. Convert the DataFrame to a dictionary.

# %%
df = pd.DataFrame([[4, 1, 5], 
                   [5, 5, 1],
                   [1, 9, 3], 
                   [8, 5, 8]], 
                  columns=["col_A", "col_B", "col_C"])


## start your code below
dict_df = df.to_dict()
## end your code here

print(dict_df)
# Out:
# {'col_A': {0: 4, 1: 5, 2: 1, 3: 8}, 'col_B': {0: 1, 1: 5, 2: 9, 3: 5}, 'col_C': {0: 5, 1: 1, 2: 3, 3: 8}}

# %% [markdown]
# ### 201-210: As your next exercise, frame 10 questions on your own and solve them.

# %% [markdown]
# Great Job solving this notebook. Go to NumPy Notebook 1: [Link](https://deepnote.com/workspace/avi-chawla-695b-aee6f4ef-2d50-4fb6-9ef2-20ee1022995a/project/Numpy-part-1-9b9979f2-b708-4292-b466-3d0157564c91/%2Fnotebook.ipynb)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a74008ef-c0cb-4680-94b9-2b12fd9cf527' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
